# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import scipy.stats as stats
from pylab import *

# %%
df=pd.read_csv("SanFrancisco.csv",parse_dates=['Date Time'],header=int(0))

# %%
df.columns
# Out:
# Index(['Date Time', ' Water Level', ' Sigma', ' O', ' F', ' R', ' L',
#        ' Quality '],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date Time       datetime64[ns]
#  Water Level           float64
#  Sigma                 float64
#  O                       int64
#  F                       int64
#  R                       int64
#  L                       int64
#  Quality                object
# dtype: object

# %%
df.head(16)
# Out:
#              Date Time   Water Level   Sigma   O   F   R   L  Quality
# 0  2016-04-01 00:00:00         3.010   0.105   0   0   0   1         v
# 1  2016-04-01 00:06:00         3.105   0.092   0   0   0   1         v
# 2  2016-04-01 00:12:00         3.141   0.125   0   0   0   1         v
# 3  2016-04-01 00:18:00         3.184   0.151   0   0   0   1         v
# 4  2016-04-01 00:24:00         3.253   0.128   0   0   0   1         v
# 5  2016-04-01 00:30:00         3.266   0.144   0   0   0   1         v
# 6  2016-04-01 00:36:00         3.315   0.075   0   0   0   1         v
# 7  2016-04-01 00:42:00         3.358   0.115   0   0   0   1         v
# 8  2016-04-01 00:48:00         3.417   0.089   0   0   0   1         v
# 9  2016-04-01 00:54:00         3.499   0.108   0   0   0   1         v
# 10 2016-04-01 01:00:00         3.558   0.121   0   0   0   1         v
# 11 2016-04-01 01:06:00         3.623   0.095   0   0   0   1         v
# 12 2016-04-01 01:12:00         3.633   0.154   0   0   0   1         v
# 13 2016-04-01 01:18:00         3.666   0.102   0   0   0   1         v
# 14 2016-04-01 01:24:00         3.692   0.092   0   0   0   1         v
# 15 2016-04-01 01:30:00         3.702   0.095   0   0   0   1         v

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Date Time       0
#  Water Level    0
#  Sigma          2
#  O              0
#  F              0
#  R              0
#  L              0
#  Quality        0
# dtype: int64

# %%
df.columns=['Date Time','Water Level','Sigma','O','F','R','L','Quality']

# %%
x=df['Date Time']
y=df['Water Level']

# %%
plt.plot(x,y)
plt.grid(True)

plt.title('Mareas de San Francisco, CA (Abril 2016)')
plt.ylabel('Nivel del agua (m)')
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
plt.xlabel('Fecha')

# %%
plt.show()
